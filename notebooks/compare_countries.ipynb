# %%
# Cross-Country Comparison — Solar Data Discovery (Week 0)
**Objective:** Load cleaned datasets for Benin, Sierra Leone, and Togo, compare GHI/DNI/DHI across countries, run statistical tests, and summarize key observations.
# Out:
#   Cell In[1], line 2
#     **Objective:** Load cleaned datasets for Benin, Sierra Leone, and Togo, compare GHI/DNI/DHI across countries, run statistical tests, and summarize key observations.
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

plt.style.use('seaborn-whitegrid')
# %matplotlib inline
